# %%
# IMPORTS
import sys
# !conda install --yes --prefix {sys.prefix} beautifulsoup4
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.4.9
#   latest version: 4.4.10
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.

# %%
# Imports - these provided for you. Do not import any other packages
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup

# %%
# 

testing2 = pd.read_csv('Workbook1.csv',encoding = "ISO-8859-1")
testing2
# Out:
#               agency                            Charge_Description_Orig  \
# 0          SAN DIEGO                            GRAND THEFT FROM PERSON
# 1      HARBOR POLICE                           SELL LIQUOR TO MINOR (M)
# 2      HARBOR POLICE  DRUNK IN PUBLIC: ALCOHOL, DRUGS, COMBO OR TOLU...
# 3      HARBOR POLICE  DRUNK IN PUBLIC: ALCOHOL, DRUGS, COMBO OR TOLU...
# 4      HARBOR POLICE                  POSS NARCOTIC CONTROLLED SUBS (M)
# 5          SAN DIEGO      POSSESS MARIJUANA 1 OZ OR  LESS WHILE DRIVING
# 6      HARBOR POLICE    MANUFACTURE/SALE/POSSESS/ETC METAL KNUCKLES (M)
# 7      HARBOR POLICE        MINOR:KNOWINGLY OPER VEH W/CARRYING ALC (M)
# 8      HARBOR POLICE              USE/UNDER INFL OF CONTROLLED SUBS (M)
# 9      HARBOR POLICE                          BURGLARY (COMMERCIAL) (F)
# 10         SAN DIEGO  TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT...
# 11         SAN DIEGO  ADULT POSSESS MARIJUANA ON GROUNDS DURING SCH ...
# ...

# %%
#testing = pd.read_csv('crime_data_w_population_and_crime_rate.csv')

st = testing.county_name

def extract_state(x):
    return x[x.find(',')+1 : ]
    

testing_with_state = testing.copy(deep = True)
testing_with_state['State'] = st.apply(extract_state)
testing_with_state
# Out:
#                        county_name  crime_rate_per_100000  index  EDITION  \
# 0               St. Louis city, MO            1791.995377      1        1
# 1            Crittenden County, AR            1754.914968      2        1
# 2             Alexander County, IL            1664.700485      3        1
# 3                Kenedy County, TX            1456.310680      4        1
# 4               De Soto Parish, LA            1447.402430      5        1
# 5               Baltimore city, MD            1419.537569      6        1
# 6                Shelby County, TN            1315.003752      7        1
# 7              Marlboro County, SC            1253.437132      8        1
# 8                Storey County, NV            1217.656012      9        1
# 9         District of Columbia, DC            1216.801325     10        1
# 10               Dillon County, SC            1165.583272     11        1
# 11                Scott County, MO            1163.145839     12        1
# ...
